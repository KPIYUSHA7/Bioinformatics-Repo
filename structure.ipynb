# %%
import pubchempy as pcp
import pandas as pd
from collections import deque

# %%
data = pd.read_excel("Cymbopogon_citratus_compounds.xlsx", header=None)

# %%
(data)
# Out:
#                                  0
# 0                      1,8-CINEOLE
# 1   ALPHA-BETA-DIHYDROPSEUDOIONONE
# 2                 ALPHA-CAMPHORENE
# 3                     ALPHA-PINENE
# 4                  ALPHA-TERPINEOL
# 5         BETA-DIHYDROPSEUDOIONONE
# 6                      CAPRIC-ACID
# 7                    CAPRYLIC-ACID
# 8                    CARYOPHYLLENE
# 9                    CERYL-ALCOHOL
# 10                          CITRAL
# 11                     CITRONELLAL
# 12                CITRONELLIC-ACID
# 13                     CITRONELLOL
# 14             CITRONELLYL-ACETATE
# 15                     CYMBOPOGONE
# 16                    CYMBOPOGONOL
# 17                    CYMBOPOGONOL
# 18                         DECANAL
# 19                        DIACETYL
# 20                        FARNESAL
# 21                        FARNESOL
# 22                      FUCOSTEROL
# 23                        FURFURAL
# 24                    GERANIC-ACID
# 25                        GERANIOL
# ...

# %%
list_of_compounds = data[0]

# %%
len(list_of_compounds)
# Out:
# 51

# %%
for i in list_of_compounds:
    try:
        pcp.download('SDF', f'{i}.sdf', i, 'name', record_type = '2d')
    except:
        print(i)
# Out:
# ALPHA-BETA-DIHYDROPSEUDOIONONE
# BETA-DIHYDROPSEUDOIONONE
# CAPRIC-ACID
# CAPRYLIC-ACID
# CERYL-ALCOHOL
# CYMBOPOGONOL
